# %% [markdown]
# <a href="https://colab.research.google.com/github/AmbiTyga/Bio-VI-BERT/blob/main/Baselines-SwinT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/rwightman/pytorch-image-models.git -q
# !pip install pytorch-lightning -q
# !pip install git+https://github.com/jacobgil/pytorch-grad-cam.git -q
# Out:
#   Building wheel for timm (setup.py) ... done
#      |████████████████████████████████| 849kB 17.6MB/s
#      |████████████████████████████████| 829kB 52.6MB/s
#      |████████████████████████████████| 276kB 38.4MB/s
#      |████████████████████████████████| 112kB 54.2MB/s
#      |████████████████████████████████| 184kB 45.1MB/s
#      |████████████████████████████████| 1.3MB 45.6MB/s
#      |████████████████████████████████| 143kB 26.7MB/s
#      |████████████████████████████████| 296kB 59.0MB/s
#   Building wheel for future (setup.py) ... done
#   Building wheel for PyYAML (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for grad-cam (PEP 517) ... done

# %%
# !wget https://raw.githubusercontent.com/AmbiTyga/Bio-VI-BERT/main/Train.7z
!7z x /content/Train.7z
# Out:
# --2021-05-05 05:34:31--  https://raw.githubusercontent.com/AmbiTyga/Bio-VI-BERT/main/Train.7z
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13524763 (13M) [application/octet-stream]
# Saving to: ‘Train.7z’
#
# Train.7z            100%[===================>]  12.90M  --.-KB/s    in 0.08s
#
# 2021-05-05 05:34:32 (168 MB/s) - ‘Train.7z’ saved [13524763/13524763]
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 13524763 bytes (13 MiB)
#
# Extracting archive: /content/Train.7z
# --
# Path = /content/Train.7z
# Type = 7z
# Physical Size = 13524763
# Headers Size = 13084
# Method = LZMA2:24
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 17
# Files: 1451
# Size:       15238342
# Compressed: 13524763

# %%
# !wget https://raw.githubusercontent.com/AmbiTyga/Bio-VI-BERT/main/Val.7z
!7z x /content/Val.7z
# Out:
# --2021-05-05 05:34:33--  https://raw.githubusercontent.com/AmbiTyga/Bio-VI-BERT/main/Val.7z
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4593856 (4.4M) [application/octet-stream]
# Saving to: ‘Val.7z’
#
# Val.7z              100%[===================>]   4.38M  --.-KB/s    in 0.05s
#
# 2021-05-05 05:34:33 (80.9 MB/s) - ‘Val.7z’ saved [4593856/4593856]
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 4593856 bytes (4487 KiB)
#
# Extracting archive: /content/Val.7z
# --
# Path = /content/Val.7z
# Type = 7z
# Physical Size = 4593856
# Headers Size = 5093
# Method = LZMA2:6m
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 17
# Files: 486
# Size:       5092491
# Compressed: 4593856

# %%
import timm
import pandas as pd
import numpy as np
import torch.nn as nn
import torch
from torch.utils.data import Dataset, DataLoader, sampler
from sklearn.preprocessing import LabelEncoder
import os
from sklearn.model_selection import train_test_split
from glob import glob
from PIL import Image
from torchvision import transforms
import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping

from pytorch_lightning.callbacks import ModelCheckpoint

import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Labeling

# %%
from glob import glob
images = [x for x in glob('./val/*/*') if 'val.csv' not in x]
for i in images:
  Image.open(i).convert('RGB').save(i)

# %%
train = pd.read_csv('/content/train/train.csv')
val = pd.read_csv('/content/val/val.csv')

# %%
train_transformer = transforms.Compose([
        transforms.Resize((224,224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
val_transformer = transforms.Compose([
        transforms.Resize((224,224)),
#         transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

# %%
class SpeciesDataset(Dataset):
  def __init__(self,csv_file,transform,x):
    super().__init__()
    csv = csv_file[[f'{x}_label','img_path']]
    self.labels = csv[f'{x}_label'].values

    self.images = csv['img_path'].values
    self.transform = transform

    # self.LE = LabelEncoder()
    # self.labels = self.LE.fit_transform(labels)    

  def __len__(self):
    # return size of dataset
    return len(self.images)

  def __getitem__(self, index):
    img = Image.open(self.images[index])
    img = self.transform(img)

    label = self.labels[index]

    return {'images':img, 'labels':label}

# %%
class SwinT(pl.LightningModule):
  def __init__(
      self,
      num_classes_classifier,
      train_weights,
      val_weights,
      train_dataset,
      val_dataset,
      sampling_rate):
    super().__init__()
    self.tr = sampling_rate[0]
    self.vr = sampling_rate[1]
    self.tw = train_weights
    self.vw = val_weights

    self.train_dataset = train_dataset
    self.val_dataset = val_dataset

    self.loss_fn = nn.CrossEntropyLoss()

    self.img_transformer = timm.models.swin_base_patch4_window7_224_in22k(pretrained=True,num_classes = num_classes_classifier)
    
  def forward(self,img):  
    return self.img_transformer(img)

  def train_dataloader(self):
    return torch.utils.data.DataLoader(
        self.train_dataset,
        batch_size=32,
        sampler=torch.utils.data.WeightedRandomSampler(self.tw,num_samples=self.tr),
        num_workers = os.cpu_count()
        )

  def val_dataloader(self):
    return torch.utils.data.DataLoader(
        self.val_dataset,
        batch_size = 32,
        sampler = torch.utils.data.WeightedRandomSampler(self.vw,num_samples=self.vr),
        num_workers = os.cpu_count()
        )
    
  def training_step(self, batch ,batch_idx):
    images = batch["images"]
    labels = batch['labels']
    outputs = self(img=images)
    loss = self.loss_fn(outputs,labels)
    acc = (outputs.argmax(dim=1).view(labels.size()).data == labels.data).sum()/labels.size(0)
    
    # self.log("loss",loss,prog_bar=True)
    self.log("accuracy",acc,prog_bar=True)
    return {"loss": loss,'accuracy':acc}

  def validation_step(self, batch ,batch_idx):
    images = batch["images"]
    labels = batch['labels']
    outputs = self(img=images)
    loss = self.loss_fn(outputs,labels)
    acc = (outputs.argmax(dim=1).view(labels.size()).data == labels.data).sum()/labels.size(0)
    
    return {"val_loss": loss.item(),'val_accuracy':acc.item()}
  
  def validation_epoch_end(self, outputs):
    avg_loss = torch.tensor(
            [output["val_loss"] 
            for output in outputs]
            ).mean()
    avg_acc = torch.tensor(
            [output["val_accuracy"] 
            for output in outputs]
            ).mean()
    
    self.log("val_loss",avg_loss,prog_bar=True)
    self.log("val_accuracy",avg_acc,prog_bar=True)

  def configure_optimizers(self):
    optimizer = [torch.optim.AdamW(
            self.parameters(), 
            lr=1e-4
        )]
    return optimizer

# %% [markdown]
# # Class

# %%
le = LabelEncoder()

train['class_label'] = le.fit_transform(train['class'])
val['class_label'] = le.transform(val['class'])

# %%
class_counts = train['class_label'].value_counts().to_dict()
train_weights = torch.tensor([1/class_counts[label] for label in train['class_label'].values])

train_dataset = SpeciesDataset(train,train_transformer,'class')

class_counts = val['class_label'].value_counts().to_dict()
val_weights = torch.tensor([1/class_counts[label] for label in val['class_label'].values])

val_dataset = SpeciesDataset(val,val_transformer,'class')

# %%
model = SwinT(
    num_classes_classifier=7,
    train_weights=train_weights,
    val_weights=val_weights,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    sampling_rate = [3360,1155]
    )
# Out:
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_base_patch4_window7_224_22k.pth" to /root/.cache/torch/hub/checkpoints/swin_base_patch4_window7_224_22k.pth

# %%
early_stop_callback = EarlyStopping(
   monitor='val_accuracy',
   min_delta=0.00,
   patience=20,
   verbose=False,
   mode='max'
)

model_ckpt = ModelCheckpoint(
    monitor='val_accuracy',
    dirpath='./',
    filename='vit-{val_loss:.2f}-{val_accuracy:.2f}',
    mode='max')

trainer = pl.Trainer(gpus=1,max_epochs=120,accumulate_grad_batches=4,num_sanity_val_steps=2,callbacks=[early_stop_callback,model_ckpt])
trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name            | Type             | Params
# -----------------------------------------------------
# 0 | loss_fn         | CrossEntropyLoss | 0
# 1 | img_transformer | SwinTransformer  | 86.8 M
# -----------------------------------------------------
# 86.8 M    Trainable params
# 0         Non-trainable params
# 86.8 M    Total params
# 347.002   Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:68: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   warnings.warn(*args, **kwargs)
# 1

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import classification_report, confusion_matrix

val_dataset = SpeciesDataset(val,val_transformer,'class')
val_loader = torch.utils.data.DataLoader(val_dataset,batch_size=51)

model = SwinT.load_from_checkpoint("/content/vit-val_loss=0.51-val_accuracy=0.89.ckpt",num_classes_classifier=7,
    train_weights=None,
    val_weights=None,
    train_dataset=None,
    val_dataset=None,
    sampling_rate = [0,0]
    )
model.cuda()
model.eval()
preds = np.array([])
label = np.array([])
with torch.no_grad():
  for batch in val_loader:
    images = batch["images"].cuda()
    labels = batch['labels']
    label = np.append(label,labels)
    prediction = model(images)
    preds = np.append(preds,prediction.argmax(dim=1).view(labels.size()).cpu().numpy())


print(classification_report(label,preds,target_names=le.classes_))
# Out:
#                precision    recall  f1-score   support
#
#  Aconoidasida       0.98      1.00      0.99       165
#       Cestoda       0.80      0.72      0.76        50
#   Chromadorea       0.84      0.91      0.87        95
#   Conoidasida       0.98      0.99      0.98        80
#       Enoplea       0.75      0.72      0.73        25
#     Tubulinea       0.97      0.94      0.96        35
# Zooflagellate       1.00      0.86      0.92        35
#
#      accuracy                           0.92       485
#     macro avg       0.90      0.88      0.89       485
#  weighted avg       0.92      0.92      0.92       485

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
confusion = confusion_matrix(label,preds)
df_cm = pd.DataFrame(confusion, index = le.classes_,
                  columns = le.classes_)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.show()

# %%
le.classes_
# Out:
# array(['Aconoidasida', 'Cestoda', 'Chromadorea', 'Conoidasida', 'Enoplea',
#        'Tubulinea', 'Zooflagellate'], dtype=object)

# %%
# !pip install ttach
# Out:
# Collecting ttach
#   Downloading https://files.pythonhosted.org/packages/8d/a3/ee48a184a185c1897c582c72240c2c8a0d0aeb5f8051a71d4e4cd930c52d/ttach-0.0.3-py3-none-any.whl
# Installing collected packages: ttach
# Successfully installed ttach-0.0.3

# %%
# !unzip -q /content/SwinT.zip

# %% [markdown]
# ### GradCam

# %%
model.eval()

# %%
def reshape_transform(tensor, height=7, width=7):
    result = tensor.reshape(tensor.size(0), 
        height, width, tensor.size(2))

    # Bring the channels to the first dimension,
    # like in CNNs.
    result = result.transpose(2, 3).transpose(1, 2)
    return result

# %%
from pytorch_grad_cam import GradCAMPlusPlus
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image

target_layer = model.img_transformer.layers[-1].blocks[-1].norm1
cam = GradCAMPlusPlus(model=model, 
                      target_layer=target_layer, 
                      reshape_transform=reshape_transform)

def plot_get(img_path,class_idx):
  rgb_img = cv2.imread(img_path, 1)[:, :, ::-1]
  rgb_img = cv2.resize(rgb_img, (224, 224))
  rgb_img = np.float32(rgb_img) / 255
  input_tensor = preprocess_image(rgb_img, mean=(0.485, 0.456, 0.406), 
                                          std=(0.229, 0.224, 0.225)).cuda()
  grayscale_cam = cam(input_tensor=input_tensor,
                    target_category=class_idx,
                    eigen_smooth=True,
                    aug_smooth=True)

  grayscale_cam = grayscale_cam[0, :]
  img_path = img_path.split('/')
  save_path = '/'.join(img_path[:6])+'/'+img_path[4]+'='+img_path[6]    
  cam_image = show_cam_on_image(rgb_img, grayscale_cam)
  cv2.imwrite(save_path, cam_image)
  torch.cuda.empty_cache()
  return Image.fromarray(cam_image)

# %% [markdown]
# #### Images

# %%
# !unzip -q /content/SwinT.zip

# %%
plot_get(
    "/content/SwinT/Class/Aconoidasida/Falciparium/Pf_gametocyte_thinF_0_232.jpg",
    0
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B0504E190>

# %%
plot_get(
    "/content/SwinT/Class/Aconoidasida/Ovale/Po_gametocyte_thickB_0_285.jpg",
    0
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B056570D0>

# %%
plot_get(
    "/content/SwinT/Class/Aconoidasida/Vivax/Pv_troph_thinC_0_312.jpg",
    0
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04F86B90>

# %%
plot_get(
    "/content/SwinT/Class/Chromadorea/Stercoralis/S_stercoralis_intbiopsy_400x_BAM1_0_367.jpg",
    2
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04FC2090>

# %%
plot_get(
    "/content/SwinT/Class/Chromadorea/Stercoralis1K/S_stercoralis_intbiopsy_1000x_BAM1_0_366.jpg",
    2
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04F869D0>

# %%
plot_get(
    "/content/SwinT/Class/Chromadorea/vermicularis/E_vermicularis_eggs_tissue2_0_157.jpg",
    2
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04FC2690>

# %%
plot_get(
    "/content/SwinT/Class/Zooflagellate/Giardia_cyst_dic/Giardia_cyst_dic2_0_165.jpg",
    6
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B0503C710>

# %%
plot_get(
    "/content/SwinT/Class/Zooflagellate/Giardia_cyst_tric/Giardia_cyst_tric4_0_174.jpg",
    6
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04FA6810>

# %%
plot_get(
    "/content/SwinT/Class/Zooflagellate/Giardia_cyst_wtmt/Giardia_cyst_wtmt4_0_163.jpg",
    6
)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04FA61D0>

# %%
# !zip -r SwinNew.zip SwinT

# %% [markdown]
# # Phylum

# %%
le = LabelEncoder()

train['phylum_label'] = le.fit_transform(train['phylum'])
val['phylum_label'] = le.transform(val['phylum'])

# %%
class_counts = train['phylum_label'].value_counts().to_dict()
train_weights = torch.tensor([1/class_counts[label] for label in train['phylum_label'].values])

train_dataset = SpeciesDataset(train, train_transformer,'phylum')

class_counts = val['phylum_label'].value_counts().to_dict()
val_weights = torch.tensor([1/class_counts[label] for label in val['phylum_label'].values])

val_dataset = SpeciesDataset(val, val_transformer,'phylum')

# %%
le.classes_
# Out:
# array(['Amoebozoa', 'Apicomplexa', 'Nematoda', 'Platyhelminthes',
#        'Sarcomastigophora'], dtype=object)

# %%
model = SwinT(
    num_classes_classifier=5,
    train_weights=train_weights,
    val_weights=val_weights,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    sampling_rate = [3550,1225]
    )

# %%
torch.cuda.empty_cache()

# %%
early_stop_callback = EarlyStopping(
   monitor='val_accuracy',
   min_delta=0.00,
   patience=20,
   verbose=False,
   mode='max'
)

model_ckpt = ModelCheckpoint(
    monitor='val_accuracy',
    dirpath='./',
    filename='swin-{val_loss:.2f}-{val_accuracy:.2f}',
    mode='max')

trainer = pl.Trainer(gpus=1,max_epochs=120,accumulate_grad_batches=4,num_sanity_val_steps=2,callbacks=[early_stop_callback,model_ckpt])
trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name            | Type             | Params
# -----------------------------------------------------
# 0 | loss_fn         | CrossEntropyLoss | 0
# 1 | img_transformer | SwinTransformer  | 86.7 M
# -----------------------------------------------------
# 86.7 M    Trainable params
# 0         Non-trainable params
# 86.7 M    Total params
# 346.993   Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:68: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   warnings.warn(*args, **kwargs)
# 1

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import classification_report, confusion_matrix

val_dataset = SpeciesDataset(val, val_transformer,'phylum')
val_loader = torch.utils.data.DataLoader(val_dataset,batch_size=51)

model = SwinT.load_from_checkpoint("/content/phylum-val_loss=0.51-val_accuracy=0.90.ckpt",
                                        num_classes_classifier=5,
                                        train_weights=None,
                                        val_weights=None,
                                        train_dataset=None,
                                        val_dataset=None,
                                        sampling_rate = [0,0]
                                        )
model.cuda()
model.eval()
preds = np.array([])
label = np.array([])
with torch.no_grad():
  for batch in val_loader:
    images = batch["images"].cuda()
    labels = batch['labels']
    label = np.append(label,labels)
    prediction = model(images)
    preds = np.append(preds,prediction.argmax(dim=1).view(labels.size()).cpu().numpy())


print(classification_report(label,preds,target_names=le.classes_))
# Out:
#                    precision    recall  f1-score   support
#
#         Amoebozoa       1.00      0.97      0.99        35
#       Apicomplexa       0.98      1.00      0.99       245
#          Nematoda       0.86      0.99      0.92       120
#   Platyhelminthes       0.94      0.62      0.75        50
# Sarcomastigophora       1.00      0.86      0.92        35
#
#          accuracy                           0.94       485
#         macro avg       0.96      0.89      0.91       485
#      weighted avg       0.95      0.94      0.94       485

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
confusion = confusion_matrix(label,preds)
df_cm = pd.DataFrame(confusion, index = le.classes_,
                  columns = le.classes_)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.show()

# %%
# !unzip /content/ResNet200D.zip

# %% [markdown]
# ### GradCam

# %%
le.classes_
# Out:
# array(['Amoebozoa', 'Apicomplexa', 'Nematoda', 'Platyhelminthes',
#        'Sarcomastigophora'], dtype=object)

# %%
def reshape_transform(tensor, height=7, width=7):
    result = tensor.reshape(tensor.size(0), 
        height, width, tensor.size(2))

    # Bring the channels to the first dimension,
    # like in CNNs.
    result = result.transpose(2, 3).transpose(1, 2)
    return result

# %%
from pytorch_grad_cam import GradCAMPlusPlus
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image

target_layer = model.img_transformer.layers[-1].blocks[-1].norm1
cam = GradCAMPlusPlus(model=model, 
                      target_layer=target_layer, 
                      reshape_transform=reshape_transform)

def plot_get(img_path,class_idx):
  rgb_img = cv2.imread(img_path, 1)[:, :, ::-1]
  rgb_img = cv2.resize(rgb_img, (224, 224))
  rgb_img = np.float32(rgb_img) / 255
  input_tensor = preprocess_image(rgb_img, mean=(0.485, 0.456, 0.406), 
                                          std=(0.229, 0.224, 0.225)).cuda()
  grayscale_cam = cam(input_tensor=input_tensor,
                    target_category=class_idx,
                    eigen_smooth=True,
                    aug_smooth=True)

  grayscale_cam = grayscale_cam[0, :]
  img_path = img_path.split('/')
  save_path = '/'.join(img_path[:6])+'/'+img_path[4]+'='+img_path[6]    
  cam_image = show_cam_on_image(rgb_img, grayscale_cam)
  cv2.imwrite(save_path, cam_image)
  return Image.fromarray(cam_image)

# %%
plot_get("/content/SwinT/Phylum/Apicomplexa/Pf_rings_thick/Pf_rings_thickC_3_214.jpg",1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B645D3C10>

# %%
plot_get("/content/SwinT/Phylum/Apicomplexa/Pf_rings_thin/Pf_rings_thinE_0_213.jpg",1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04E67290>

# %%
plot_get("/content/SwinT/Phylum/Apicomplexa/Sarcocystis/Sarcocystis_muscle_HE_MI_2_rotated_0_345.jpg",1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B04E67350>

# %%
plot_get("/content/SwinT/Phylum/Nematoda/Ascaris cuticle/Ascaris_cuticle_cross_section_0_40.jpg",2)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B6456C810>

# %%
plot_get("/content/SwinT/Phylum/Nematoda/Trichuris and Ecoli/Trichuris_and_Ecoli_HB_0_371.jpg",2)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B05649E90>

# %%
plot_get("/content/SwinT/Phylum/Nematoda/lumbricoides/A_lumbricoides_infert_Leiden_B_0_22.jpg",2)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B05559050>

# %%
plot_get("/content/SwinT/Phylum/Sarcomastigophora/Giardia cyst/Giardia_cyst_tric2_3_169.jpg",4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B645D3A10>

# %%
plot_get("/content/SwinT/Phylum/Sarcomastigophora/Giardia cyst-2/Giardia_cyst_tric10_0_171.jpg",4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B645D1750>

# %%
plot_get("/content/SwinT/Phylum/Sarcomastigophora/Giardia troph/Giardia_troph_VT_0_181.jpg",4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F3B64572450>

# %%
# !zip -r SwinNew+.zip SwinT
# Out:
#   adding: SwinT/ (stored 0%)
#   adding: SwinT/Phylum/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst/Giardia_cyst_tric2_3_169.jpg (deflated 2%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst/Sarcomastigophora=Giardia_cyst_tric2_3_169.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia troph/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia troph/Sarcomastigophora=Giardia_troph_VT_0_181.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia troph/Giardia_troph_VT_0_181.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst-2/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst-2/Giardia_cyst_tric10_0_171.jpg (deflated 2%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst-2/Sarcomastigophora=Giardia_cyst_tric10_0_171.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/Trichuris and Ecoli/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/Trichuris and Ecoli/Trichuris_and_Ecoli_HB_0_371.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/Trichuris and Ecoli/Nematoda=Trichuris_and_Ecoli_HB_0_371.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/Ascaris cuticle/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/Ascaris cuticle/Nematoda=Ascaris_cuticle_cross_section_0_40.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/Ascaris cuticle/Ascaris_cuticle_cross_section_0_40.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/lumbricoides/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/lumbricoides/A_lumbricoides_infert_Leiden_B_0_22.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/lumbricoides/Nematoda=A_lumbricoides_infert_Leiden_B_0_22.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Sarcocystis/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Sarcocystis/Apicomplexa=Sarcocystis_muscle_HE_MI_2_rotated_0_345.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/Sarcocystis/Sarcocystis_muscle_HE_MI_2_rotated_0_345.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thin/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thin/Pf_rings_thinE_0_213.jpg (deflated 2%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thin/Apicomplexa=Pf_rings_thinE_0_213.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thick/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thick/Apicomplexa=Pf_rings_thickC_3_214.jpg (deflated 2%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thick/Pf_rings_thickC_3_214.jpg (deflated 4%)
#   adding: SwinT/Class/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Falciparium/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Falciparium/Pf_gametocyte_thinF_0_232.jpg (deflated 2%)
#   adding: SwinT/Class/Aconoidasida/Falciparium/Aconoidasida=Pf_gametocyte_thinF_0_232.jpg (deflated 1%)
#   adding: SwinT/Class/Aconoidasida/Vivax/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Vivax/Pv_troph_thinC_0_312.jpg (deflated 2%)
#   adding: SwinT/Class/Aconoidasida/Vivax/Aconoidasida=Pv_troph_thinC_0_312.jpg (deflated 1%)
#   adding: SwinT/Class/Aconoidasida/Ovale/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Ovale/Aconoidasida=Po_gametocyte_thickB_0_285.jpg (deflated 1%)
#   adding: SwinT/Class/Aconoidasida/Ovale/Po_gametocyte_thickB_0_285.jpg (deflated 2%)
#   adding: SwinT/Class/Zooflagellate/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_dic/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_dic/Zooflagellate=Giardia_cyst_dic2_0_165.jpg (deflated 2%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_dic/Giardia_cyst_dic2_0_165.jpg (deflated 5%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_tric/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_tric/Zooflagellate=Giardia_cyst_tric4_0_174.jpg (deflated 1%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_tric/Giardia_cyst_tric4_0_174.jpg (deflated 2%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_wtmt/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_wtmt/Giardia_cyst_wtmt4_0_163.jpg (deflated 3%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_wtmt/Zooflagellate=Giardia_cyst_wtmt4_0_163.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/Stercoralis/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/Stercoralis/Chromadorea=S_stercoralis_intbiopsy_400x_BAM1_0_367.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/Stercoralis/S_stercoralis_intbiopsy_400x_BAM1_0_367.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/Stercoralis1K/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/Stercoralis1K/S_stercoralis_intbiopsy_1000x_BAM1_0_366.jpg (deflated 2%)
#   adding: SwinT/Class/Chromadorea/Stercoralis1K/Chromadorea=S_stercoralis_intbiopsy_1000x_BAM1_0_366.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/vermicularis/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/vermicularis/E_vermicularis_eggs_tissue2_0_157.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/vermicularis/Chromadorea=E_vermicularis_eggs_tissue2_0_157.jpg (deflated 1%)
#   adding: SwinT/Species/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst tric/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst tric/Ehistdisp_cyst_tric6_KS_0_123.jpg (deflated 1%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst/Ehistdisp_cyst_tric3_0_120.jpg (deflated 2%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst wtmt/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst wtmt/Ehistdisp_cyst_wtmt_0_115.jpg (deflated 1%)
#   adding: SwinT/Species/Giardia duodenalis/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph kohn/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph kohn/Giardia_troph_kohn_0_182.jpg (deflated 2%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph/Giardia_troph_VT_0_181.jpg (deflated 1%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia_cyst_tric/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia_cyst_tric/Giardia_cyst_tric10_0_171.jpg (deflated 2%)
#   adding: SwinT/Species/Ancyclostoma/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_filariform/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_filariform/Hookworm_filariform_posterior_A_0_11.jpg (deflated 4%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_rhabditiform/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_rhabditiform/Hookworm_rhabditiform_2_0_7.jpg (deflated 2%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm/Hookworm_2x2_B_0_3.jpg (deflated 1%)

# %% [markdown]
# # Species

# %%
le = LabelEncoder()

train['species_label'] = le.fit_transform(train['species'])
val['species_label'] = le.transform(val['species'])

# %%
class_counts = train['species_label'].value_counts().to_dict()
train_weights = torch.tensor([1/class_counts[label] for label in train['species_label'].values])

train_dataset = SpeciesDataset(train, train_transformer,'species')

class_counts = val['species_label'].value_counts().to_dict()
val_weights = torch.tensor([1/class_counts[label] for label in val['species_label'].values])

val_dataset = SpeciesDataset(val, val_transformer,'species')

# %%
len(le.classes_)
# Out:
# 16

# %%
model = SwinT(
    num_classes_classifier=16,
    train_weights=train_weights,
    val_weights=val_weights,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    sampling_rate = [2160,720]
    )

# %%
early_stop_callback = EarlyStopping(
   monitor='val_accuracy',
   min_delta=0.00,
   patience=20,
   verbose=False,
   mode='max'
)

model_ckpt = ModelCheckpoint(
    monitor='val_accuracy',
    dirpath='./',
    filename='species-{val_loss:.2f}-{val_accuracy:.2f}',
    mode='max')

trainer = pl.Trainer(gpus=1,max_epochs=120,accumulate_grad_batches=4,num_sanity_val_steps=2,callbacks=[early_stop_callback,model_ckpt])
trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name            | Type             | Params
# -----------------------------------------------------
# 0 | loss_fn         | CrossEntropyLoss | 0
# 1 | img_transformer | SwinTransformer  | 86.8 M
# -----------------------------------------------------
# 86.8 M    Trainable params
# 0         Non-trainable params
# 86.8 M    Total params
# 347.038   Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…

# %% [markdown]
# ### Accuracy

# %%
from sklearn.metrics import classification_report, confusion_matrix

val_dataset = SpeciesDataset(val, val_transformer,'species')
val_loader = torch.utils.data.DataLoader(val_dataset,batch_size=51)

model = SwinT.load_from_checkpoint("/content/species-val_loss=0.89-val_accuracy=0.78.ckpt",
                                        num_classes_classifier=16,
                                        train_weights=None,
                                        val_weights=None,
                                        train_dataset=None,
                                        val_dataset=None,
                                        sampling_rate = [0,0]
                                        )
model.cuda()
model.eval()
preds = np.array([])
label = np.array([])
with torch.no_grad():
  for batch in val_loader:
    images = batch["images"].cuda()
    labels = batch['labels']
    label = np.append(label,labels)
    prediction = model(images)
    preds = np.append(preds,prediction.argmax(dim=1).view(labels.size()).cpu().numpy())


print(classification_report(label,preds,target_names=le.classes_))
# Out:
#                            precision    recall  f1-score   support
#
#          Ancyclostoma sp.       0.91      1.00      0.95        20
#      Ascaris lumbricoides       0.94      0.86      0.90        35
#       Cryptosporidium sp.       0.76      0.80      0.78        20
#   Cyclospora cayetanensis       0.88      0.90      0.89        40
#   Dibothriocephalus latus       0.68      0.68      0.68        25
#     Entamoeba histolytica       0.86      0.91      0.89        35
#   Enterobius vermicularis       0.83      0.25      0.38        20
#        Giardia duodenalis       0.97      0.86      0.91        35
#           Hymenolepis spp       0.93      0.52      0.67        25
#     Plasmodium falciparum       0.82      0.71      0.76        45
#       Plasmodium malariae       0.66      0.78      0.71        40
#          Plasmodium ovale       0.54      0.57      0.56        35
#          Plasmodium vivax       0.67      0.62      0.64        45
#           Sarcocystis sp.       1.00      1.00      1.00        20
# Strongyloides stercoralis       0.65      0.85      0.74        20
#       Trichuris Trichuria       0.51      0.92      0.66        25
#
#                  accuracy                           0.76       485
#                 macro avg       0.79      0.76      0.76       485
#              weighted avg       0.78      0.76      0.76       485

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
confusion = confusion_matrix(label,preds)
df_cm = pd.DataFrame(confusion, index = le.classes_,
                  columns = le.classes_)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
plt.show()

# %%
# !unzip -q /content/ResNet200D.zip

# %% [markdown]
# ### GradCam

# %%
le.classes_
# Out:
# array(['Ancyclostoma sp.', 'Ascaris lumbricoides', 'Cryptosporidium sp.',
#        'Cyclospora cayetanensis', 'Dibothriocephalus latus',
#        'Entamoeba histolytica', 'Enterobius vermicularis',
#        'Giardia duodenalis', 'Hymenolepis spp', 'Plasmodium falciparum',
#        'Plasmodium malariae', 'Plasmodium ovale', 'Plasmodium vivax',
#        'Sarcocystis sp.', 'Strongyloides stercoralis',
#        'Trichuris Trichuria'], dtype=object)

# %%
def reshape_transform(tensor, height=6, width=8):
    result = tensor[:, 1 :  , :].reshape(tensor.size(0), 
        height, width, tensor.size(2))

    # Bring the channels to the first dimension,
    # like in CNNs.
    result = result.transpose(2, 3).transpose(1, 2)
    return result

# %%
from pytorch_grad_cam import GradCAMPlusPlus
from pytorch_grad_cam.utils.image import show_cam_on_image, preprocess_image

target_layer = model.img_transformer.layers[-1].blocks[-1].norm1
cam = GradCAMPlusPlus(model=model, 
                      target_layer=target_layer, 
                      reshape_transform=reshape_transform)

def plot_get(img_path,class_idx):
  rgb_img = cv2.imread(img_path, 1)[:, :, ::-1]
  rgb_img = cv2.resize(rgb_img, (224, 224))
  rgb_img = np.float32(rgb_img) / 255
  input_tensor = preprocess_image(rgb_img, mean=[0.5, 0.5, 0.5], 
                                          std=[0.5, 0.5, 0.5]).cuda()
  grayscale_cam = cam(input_tensor=input_tensor,
                    target_category=class_idx,
                    eigen_smooth=True,
                    aug_smooth=True)

  grayscale_cam = grayscale_cam[0, :]
  img_path = img_path.split('/')
  save_path = '/'.join(img_path[:6])+'/'+img_path[4]+'='+img_path[6]    
  cam_image = show_cam_on_image(rgb_img, grayscale_cam)
  cv2.imwrite(save_path, cam_image)
  return Image.fromarray(cam_image)

# %%
plot_get("/content/SwinT/Species/Ancyclostoma/Hookworm/Hookworm_2x2_B_0_3.jpg",0)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687D112290>

# %%
plot_get("/content/SwinT/Species/Ancyclostoma/Hookworm_filariform/Hookworm_filariform_posterior_A_0_11.jpg",0)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687C3360D0>

# %%
plot_get("/content/SwinT/Species/Ancyclostoma/Hookworm_rhabditiform/Hookworm_rhabditiform_2_0_7.jpg",0)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687C36C790>

# %%
plot_get("/content/SwinT/Species/Entamoeba/Ehistdisp cyst/Ehistdisp_cyst_tric3_0_120.jpg",5)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687C2F8BD0>

# %%
plot_get("/content/SwinT/Species/Entamoeba/Ehistdisp cyst tric/Ehistdisp_cyst_tric6_KS_0_123.jpg",5)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687C336150>

# %%
plot_get("/content/SwinT/Species/Entamoeba/Ehistdisp cyst wtmt/Ehistdisp_cyst_wtmt_0_115.jpg",5)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F68C442CFD0>

# %%
plot_get("/content/SwinT/Species/Giardia duodenalis/Giardia troph/Giardia_troph_VT_0_181.jpg",7)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687C5C7090>

# %%
plot_get("/content/SwinT/Species/Giardia duodenalis/Giardia troph kohn/Giardia_troph_kohn_0_182.jpg",7)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687C36C050>

# %%
plot_get("/content/SwinT/Species/Giardia duodenalis/Giardia_cyst_tric/Giardia_cyst_tric10_0_171.jpg",7)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:795: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F687C36C750>

# %%
# !zip -r Swin++.zip SwinT
# Out:
#   adding: SwinT/ (stored 0%)
#   adding: SwinT/Phylum/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thin/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thin/Apicomplexa=Pf_rings_thinE_0_213.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thin/Pf_rings_thinE_0_213.jpg (deflated 2%)
#   adding: SwinT/Phylum/Apicomplexa/Sarcocystis/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Sarcocystis/Apicomplexa=Sarcocystis_muscle_HE_MI_2_rotated_0_345.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/Sarcocystis/Sarcocystis_muscle_HE_MI_2_rotated_0_345.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thick/ (stored 0%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thick/Apicomplexa=Pf_rings_thickC_3_214.jpg (deflated 1%)
#   adding: SwinT/Phylum/Apicomplexa/Pf_rings_thick/Pf_rings_thickC_3_214.jpg (deflated 4%)
#   adding: SwinT/Phylum/Nematoda/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/Ascaris cuticle/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/Ascaris cuticle/Nematoda=Ascaris_cuticle_cross_section_0_40.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/Ascaris cuticle/Ascaris_cuticle_cross_section_0_40.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/Trichuris and Ecoli/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/Trichuris and Ecoli/Trichuris_and_Ecoli_HB_0_371.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/Trichuris and Ecoli/Nematoda=Trichuris_and_Ecoli_HB_0_371.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/lumbricoides/ (stored 0%)
#   adding: SwinT/Phylum/Nematoda/lumbricoides/Nematoda=A_lumbricoides_infert_Leiden_B_0_22.jpg (deflated 1%)
#   adding: SwinT/Phylum/Nematoda/lumbricoides/A_lumbricoides_infert_Leiden_B_0_22.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia troph/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia troph/Sarcomastigophora=Giardia_troph_VT_0_181.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia troph/Giardia_troph_VT_0_181.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst/Sarcomastigophora=Giardia_cyst_tric2_3_169.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst/Giardia_cyst_tric2_3_169.jpg (deflated 2%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst-2/ (stored 0%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst-2/Sarcomastigophora=Giardia_cyst_tric10_0_171.jpg (deflated 1%)
#   adding: SwinT/Phylum/Sarcomastigophora/Giardia cyst-2/Giardia_cyst_tric10_0_171.jpg (deflated 2%)
#   adding: SwinT/Class/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/vermicularis/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/vermicularis/Chromadorea=E_vermicularis_eggs_tissue2_0_157.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/vermicularis/E_vermicularis_eggs_tissue2_0_157.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/Stercoralis1K/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/Stercoralis1K/S_stercoralis_intbiopsy_1000x_BAM1_0_366.jpg (deflated 2%)
#   adding: SwinT/Class/Chromadorea/Stercoralis1K/Chromadorea=S_stercoralis_intbiopsy_1000x_BAM1_0_366.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/Stercoralis/ (stored 0%)
#   adding: SwinT/Class/Chromadorea/Stercoralis/Chromadorea=S_stercoralis_intbiopsy_400x_BAM1_0_367.jpg (deflated 1%)
#   adding: SwinT/Class/Chromadorea/Stercoralis/S_stercoralis_intbiopsy_400x_BAM1_0_367.jpg (deflated 1%)
#   adding: SwinT/Class/Zooflagellate/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_dic/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_dic/Zooflagellate=Giardia_cyst_dic2_0_165.jpg (deflated 1%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_dic/Giardia_cyst_dic2_0_165.jpg (deflated 5%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_tric/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_tric/Giardia_cyst_tric4_0_174.jpg (deflated 2%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_tric/Zooflagellate=Giardia_cyst_tric4_0_174.jpg (deflated 1%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_wtmt/ (stored 0%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_wtmt/Zooflagellate=Giardia_cyst_wtmt4_0_163.jpg (deflated 1%)
#   adding: SwinT/Class/Zooflagellate/Giardia_cyst_wtmt/Giardia_cyst_wtmt4_0_163.jpg (deflated 3%)
#   adding: SwinT/Class/Aconoidasida/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Vivax/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Vivax/Aconoidasida=Pv_troph_thinC_0_312.jpg (deflated 1%)
#   adding: SwinT/Class/Aconoidasida/Vivax/Pv_troph_thinC_0_312.jpg (deflated 2%)
#   adding: SwinT/Class/Aconoidasida/Falciparium/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Falciparium/Aconoidasida=Pf_gametocyte_thinF_0_232.jpg (deflated 1%)
#   adding: SwinT/Class/Aconoidasida/Falciparium/Pf_gametocyte_thinF_0_232.jpg (deflated 2%)
#   adding: SwinT/Class/Aconoidasida/Ovale/ (stored 0%)
#   adding: SwinT/Class/Aconoidasida/Ovale/Po_gametocyte_thickB_0_285.jpg (deflated 2%)
#   adding: SwinT/Class/Aconoidasida/Ovale/Aconoidasida=Po_gametocyte_thickB_0_285.jpg (deflated 1%)
#   adding: SwinT/Species/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst/Ehistdisp_cyst_tric3_0_120.jpg (deflated 2%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst/Entamoeba=Ehistdisp_cyst_tric3_0_120.jpg (deflated 1%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst wtmt/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst wtmt/Ehistdisp_cyst_wtmt_0_115.jpg (deflated 1%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst wtmt/Entamoeba=Ehistdisp_cyst_wtmt_0_115.jpg (deflated 1%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst tric/ (stored 0%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst tric/Ehistdisp_cyst_tric6_KS_0_123.jpg (deflated 1%)
#   adding: SwinT/Species/Entamoeba/Ehistdisp cyst tric/Entamoeba=Ehistdisp_cyst_tric6_KS_0_123.jpg (deflated 1%)
#   adding: SwinT/Species/Ancyclostoma/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_filariform/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_filariform/Hookworm_filariform_posterior_A_0_11.jpg (deflated 4%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_filariform/Ancyclostoma=Hookworm_filariform_posterior_A_0_11.jpg (deflated 2%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm/Hookworm_2x2_B_0_3.jpg (deflated 1%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm/Ancyclostoma=Hookworm_2x2_B_0_3.jpg (deflated 1%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_rhabditiform/ (stored 0%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_rhabditiform/Hookworm_rhabditiform_2_0_7.jpg (deflated 2%)
#   adding: SwinT/Species/Ancyclostoma/Hookworm_rhabditiform/Ancyclostoma=Hookworm_rhabditiform_2_0_7.jpg (deflated 1%)
#   adding: SwinT/Species/Giardia duodenalis/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph/Giardia_troph_VT_0_181.jpg (deflated 1%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph/Giardia duodenalis=Giardia_troph_VT_0_181.jpg (deflated 1%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph kohn/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph kohn/Giardia_troph_kohn_0_182.jpg (deflated 2%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia troph kohn/Giardia duodenalis=Giardia_troph_kohn_0_182.jpg (deflated 1%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia_cyst_tric/ (stored 0%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia_cyst_tric/Giardia_cyst_tric10_0_171.jpg (deflated 2%)
#   adding: SwinT/Species/Giardia duodenalis/Giardia_cyst_tric/Giardia duodenalis=Giardia_cyst_tric10_0_171.jpg (deflated 1%)
